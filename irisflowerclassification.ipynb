# %%
import numpy as np
import pandas as pd

# %%
import sklearn

# %%
pip install -U scikit-learn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
irisflower = pd.read_csv('/content/drive/MyDrive/Iris.csv')

# %%
irisflower.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
irisflower.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
irisflower.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
irisflower.corr()
# Out:
# <ipython-input-31-e4c73ce33a84>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   irisflower.corr()
#                      Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Id             1.000000       0.716676     -0.397729       0.882747
# SepalLengthCm  0.716676       1.000000     -0.109369       0.871754
# SepalWidthCm  -0.397729      -0.109369      1.000000      -0.420516
# PetalLengthCm  0.882747       0.871754     -0.420516       1.000000
# PetalWidthCm   0.899759       0.817954     -0.356544       0.962757
#
#                PetalWidthCm
# Id                 0.899759
# SepalLengthCm      0.817954
# SepalWidthCm      -0.356544
# PetalLengthCm      0.962757
# PetalWidthCm       1.000000

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import sklearn

# %%
sns.pairplot(irisflower)

# %%
sns.heatmap(irisflower.corr())
# Out:
# <ipython-input-33-baaccbad34d9>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(irisflower.corr())
# <Axes: >

# %%
irisflower["Species"].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
# Separate features and target  
df = irisflower.values
X = df[:,0:4]
Y = df[:,4]

# %%
data_group = irisflower.groupby("Species")
data_group

# %%
data_group.corr()
# Out:
#                                      Id  SepalLengthCm  SepalWidthCm  \
# Species
# Iris-setosa     Id             1.000000      -0.033561     -0.066688
#                 SepalLengthCm -0.033561       1.000000      0.746780
#                 SepalWidthCm  -0.066688       0.746780      1.000000
#                 PetalLengthCm  0.053253       0.263874      0.176695
#                 PetalWidthCm   0.087492       0.279092      0.279973
# Iris-versicolor Id             1.000000      -0.269056     -0.081867
#                 SepalLengthCm -0.269056       1.000000      0.525911
#                 SepalWidthCm  -0.081867       0.525911      1.000000
#                 PetalLengthCm -0.189481       0.754049      0.560522
#                 PetalWidthCm  -0.168846       0.546461      0.663999
# Iris-virginica  Id             1.000000      -0.012549      0.130884
#                 SepalLengthCm -0.012549       1.000000      0.457228
# ...

# %%
def converter(s):
  s = s.lower()
  if s == 'iris-setosa':
    return 0
  elif s == 'iris-versicolor':
    return 1
  elif s == 'iris-virginica':
    return 2
  else:
    return -1

# %%
data = pd.read_csv("/content/drive/MyDrive/Iris.csv", converters = {"Species":converter})

# %%
features = data[['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']]
labels = data["Species"]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
# %matplotlib inline

# %%
df = irisflower.values
X = df[:,0:4]
Y = df[:,4]

# %%
columns = ['Sepal length', 'Sepal width', 'Petal length', 'Petal width', 'Species']

# %%
unique_labels = np.unique(Y)
num_labels = len(unique_labels)
num_features = X.shape[1]

Y_Data = np.zeros((num_features, num_labels), dtype=np.float32)

for i in range(num_features):
    for j, label in enumerate(unique_labels):
        Y_Data[i, j] = np.average(X[:, i][Y == label].astype(np.float32))

Y_Data_reshaped = np.swapaxes(Y_Data, 0, 1)
X_axis = np.arange(num_features)
width = 0.25

# %%
plt.bar(X_axis, Y_Data_reshaped[0], width, label = 'Setosa')
plt.bar(X_axis+width, Y_Data_reshaped[1], width, label = 'Versicolour')
plt.bar(X_axis+width*2, Y_Data_reshaped[2], width, label = 'Virginica')
plt.xticks(X_axis, columns[:4])
plt.xlabel("Features")
plt.ylabel("Value in cm.")
plt.legend(bbox_to_anchor=(1.3,1))
plt.show()

# %%
from sklearn import tree

# %%
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report

# %%
X_train, X_test, y_train, y_test = train_test_split(features,labels,test_size = 0.3, random_state = 42)

# %%
model = DecisionTreeClassifier(criterion='entropy',max_depth=3, random_state=42)
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=3, random_state=42)

# %%
model.predict(X_test)
# Out:
# array([1, 0, 2, 1, 2, 0, 1, 2, 1, 1, 2, 0, 0, 0, 0, 1, 2, 1, 1, 2, 0, 2,
#        0, 2, 2, 2, 2, 2, 0, 0, 0, 0, 1, 0, 0, 2, 1, 0, 0, 0, 2, 1, 1, 0,
#        0])

# %%
from sklearn.svm import SVC
svn = SVC()
svn.fit(X_train, y_train)
# Out:
# SVC()

# %%
pred = svn.predict(X_test)
accuracy_score(y_test, pred)
# Out:
# 1.0

# %%
print(classification_report(y_test, pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        19
#            1       1.00      1.00      1.00        13
#            2       1.00      1.00      1.00        13
#
#     accuracy                           1.00        45
#    macro avg       1.00      1.00      1.00        45
# weighted avg       1.00      1.00      1.00        45

# %%
X_new = np.array([[3, 2, 1, 0.2], [  4.9, 2.2, 3.8, 1.1 ], [  5.3, 2.5, 4.6, 1.9 ]])
#Prediction of the species from the input vector
predic = svn.predict(X_new)
print("Prediction of Species: {}".format(predic))
# Out:
# Prediction of Species: [0 1 2]
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(

# %%
import pickle
with open('SVM.pickle', 'wb') as f:
    pickle.dump(svn, f)
# Load the model
with open('SVM.pickle', 'rb') as f:
    model = pickle.load(f)
model.predict(X_new)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# array([0, 1, 2])

# %%
from sklearn.datasets import load_iris
iris = load_iris()
X, y = iris.data, iris.target
clf = tree.DecisionTreeClassifier()
clf = clf.fit(X, y)

# %%
tree.plot_tree(clf)
[...]
# Out:
# [Ellipsis]

# %%
import graphviz 
dot_data = tree.export_graphviz(clf, out_file=None) 
graph = graphviz.Source(dot_data) 
graph.render("iris")
# Out:
# 'iris.pdf'

# %%
dot_data = tree.export_graphviz(clf, out_file=None, 
                      feature_names=iris.feature_names,  
                      class_names=iris.target_names,  
                      filled=True, rounded=True,  
                      special_characters=True)  
graph = graphviz.Source(dot_data)  
graph
